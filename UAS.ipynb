# %%
# Load dataset

import pandas as pd
data = pd.read_csv('price_range_phone_dataset.csv')
data
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
data.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
#Tampilkan informasi data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
data.describe().T
# Out:
#                 count        mean          std    min      25%     50%  \
# battery_power  2000.0  1238.51850   439.418206  501.0   851.75  1226.0
# blue           2000.0     0.49500     0.500100    0.0     0.00     0.0
# clock_speed    2000.0     1.52225     0.816004    0.5     0.70     1.5
# dual_sim       2000.0     0.50950     0.500035    0.0     0.00     1.0
# fc             2000.0     4.30950     4.341444    0.0     1.00     3.0
# four_g         2000.0     0.52150     0.499662    0.0     0.00     1.0
# int_memory     2000.0    32.04650    18.145715    2.0    16.00    32.0
# m_dep          2000.0     0.50175     0.288416    0.1     0.20     0.5
# mobile_wt      2000.0   140.24900    35.399655   80.0   109.00   141.0
# n_cores        2000.0     4.52050     2.287837    1.0     3.00     4.0
# pc             2000.0     9.91650     6.064315    0.0     5.00    10.0
# px_height      2000.0   645.10800   443.780811    0.0   282.75   564.0
# ...

# %%
# Total hp dengan sc_w = 0
print(len(data[data.sc_w == 0]))
# Total hp dengan px_height = 0
print(len(data[data.px_height == 0]))
# Out:
# 180
# 2

# %%
df = data.copy()
#ubah nilai sc_w dan px_height yang 0 menjadi nilai mean dari masing2 kolom trsebut
avg_sc_w = df['sc_w'].mean()
avg_px_height = df['px_height'].mean()


df['sc_w'].replace({0:avg_sc_w}, inplace=True)
df['px_height'].replace({0:avg_px_height}, inplace=True)

# %%
# periksa lagi bahwa data tidak ada yang 0
# Total hp dengan sc_w = 0
print(len(df[df.sc_w == 0]))
# Total hp dengan px_height = 0
print(len(df[df.px_height == 0]))
# Out:
# 0
# 0

# %%
#cek apakah ada data duplikat
len(df[df.duplicated()])
# Out:
# 0

# %%
#cek apakah ada data yang null
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# ### Battery Power

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(5,5)})
ax=sns.displot(df["battery_power"])
plt.show()
# Out:
# C:\Users\ARUL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Hubungan RAM dan Price Range

# %%
df.plot(x='price_range',y='ram',kind='scatter')
plt.show()

# %% [markdown]
# ### Screen Size

# %% [markdown]
# Konversi screen_size dari cm ke inches (data sc_h dan sc_w)

# %%
# Buat variable/kolom baru dengan nama sc_size

import numpy as np

# df['sc_size'] = np.sqrt((df['sc_h']**2) + (df['sc_w']**2))
# df['sc_size'] = round(df['sc_size']/2.54, 2)

# %%
# fig, axs = plt.subplots(1,2, figsize=(15,5))
# sns.kdeplot(data=df, x='sc_size', hue='price_range', ax=axs[0])
# sns.boxplot(data=df, x='price_range', y='sc_size', ax=axs[1])
# plt.show()

# %% [markdown]
# Ukuran Layar menunjukkan sedikit variasi sepanjang variabel target. Hal ini dapat membantu dalam memprediksi kategori sasaran.

# %%
# hapus kolom sc_h dan sc_w karena sudah menggunakan kolom screen_size
# df.drop(['sc_h', 'sc_w'], axis = 1, inplace = True)

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['price_range'], axis = 1)
y = df['price_range']

# %%
X
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
X.shape
# Out:
# (2000, 20)

# %%
y.shape
# Out:
# (2000,)

# %%
# Scaling values of X

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Split data menjadi train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.1)

# %%
X_train.shape
# Out:
# (1800, 20)

# %%
y_train.shape
# Out:
# (1800,)

# %%
#confusion matrix
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
def my_confusion_matrix(y_test, y_pred, plt_title):
    cm=confusion_matrix(y_test, y_pred)
    print(classification_report(y_test, y_pred))
    sns.heatmap(cm, annot=True, fmt='g', cbar=False, cmap='BuPu')
    plt.xlabel('Predicted Values')
    plt.ylabel('Actual Values')
    plt.title(plt_title)
    plt.show()
    return cm

# %% [markdown]
# ## Decision Tree Model

# %%
#decision tree model
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier(max_depth=7,
                             min_samples_leaf=3,
                             min_samples_split=10)

# %%
from sklearn.metrics import classification_report

# Prediction

dtc.fit(X_train, y_train)
y_pred_dtc=dtc.predict(X_test)
print('Decision tree acc: ',accuracy_score(y_test,y_pred_dtc))
cm_dtc=my_confusion_matrix(y_test, y_pred_dtc, 'Confusion Matrix')
# Out:
# Decision tree acc:  0.855
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93        45
#            1       0.85      0.87      0.86        52
#            2       0.79      0.71      0.75        48
#            3       0.86      0.89      0.88        55
#
#     accuracy                           0.85       200
#    macro avg       0.85      0.86      0.85       200
# weighted avg       0.85      0.85      0.85       200

# %% [markdown]
# ### Save model

# %%
import pickle

pickle.dump(dtc,open('DTC.pkl','wb'))

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')
